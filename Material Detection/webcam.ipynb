# %%
from ultralytics import YOLO
import cv2



video_path = "C:\\Users\\almas\\Documents\\Projects\\Specs\\Images\\io.mp4"
video_path_out = "C:\\Users\\almas\\Documents\\Projects\\Specs\\Images\\io_out.mp4"

# Initialize the video capture object
cap = cv2.VideoCapture(video_path)
ret, frame = cap.read()
H, W, _ = frame.shape
# Initialize the video writer
out = cv2.VideoWriter(video_path_out, cv2.VideoWriter_fourcc(*'MP4E'), int(cap.get(cv2.CAP_PROP_FPS)), (W, H))

# Update the model path
model_path = "C:\\Users\\almas\\Documents\\Projects\\Specs\\Model\\best.pt"

# Load the YOLO model
model = YOLO(model_path)  # load a custom model

threshold = 0.5

while ret:
    results = model(frame)[0]

    for result in results.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = result

        if score > threshold:
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 4)
            cv2.putText(frame, results.names[int(class_id)].upper(), (int(x1), int(y1 - 10)),
                        cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3, cv2.LINE_AA)
    cv2.imshow('ji',frame)
    if cv2.waitKey(30) & 0xFF == ord('q'):
        break
    out.write(frame)
    


cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 metal frame, 461.7ms
# Speed: 7.3ms preprocess, 461.7ms inference, 796.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 metal frame, 422.6ms
# Speed: 14.5ms preprocess, 422.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 metal frame, 443.6ms
# Speed: 10.4ms preprocess, 443.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 metal frame, 473.3ms
# Speed: 4.3ms preprocess, 473.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 metal frame, 434.0ms
# Speed: 11.5ms preprocess, 434.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 metal frame, 456.6ms
# Speed: 10.0ms preprocess, 456.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 metal frame, 424.4ms
# Speed: 0.0ms preprocess, 424.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
import cv2
from ultralytics import YOLO
import easyocr 

# Path to the YOLO model
model_path = "C:\\Users\\almas\\Documents\\Projects\\Specs\\Model\\best.pt"

# Load the YOLO model
model = YOLO(model_path)

# Open the webcam
cap = cv2.VideoCapture(1)
reader=easyocr.Reader(['en'],gpu=True)

# Check if the webcam is opened correctly
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

# Define the detection threshold
threshold = 0.5

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    if not ret:
        print("Error: Failed to capture image.")
        break

    # Get the height and width of the frame
    H, W, _ = frame.shape

    # Get results from the YOLO model
    results = model(frame)[0]

    # Iterate over the results
    for result in results.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = result

        if score > threshold:
            # Draw the bounding box
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 4)
            # Put the class label text
            cv2.putText(frame, results.names[int(class_id)].upper(), (int(x1), int(y1 - 10)),
                        cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3, cv2.LINE_AA)

    cv2.imshow('Webcam YOLO Detection', frame)
    roi = frame[int(y1):int(y2), int(x1):int(x2)]
    text=reader.readtext(roi)
    for t in text:
        print(f"Extracted text: {t[1]}")
    if cv2.waitKey(30) & 0xFF == ord('q'):
        break

# Release the webcam and destroy all OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 0: 480x640 (no detections), 726.3ms
# Speed: 0.0ms preprocess, 726.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 559.0ms
# Speed: 2.8ms preprocess, 559.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 539.0ms
# Speed: 2.2ms preprocess, 539.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 522.7ms
# Speed: 0.0ms preprocess, 522.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 546.2ms
# Speed: 1.1ms preprocess, 546.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 544.3ms
# Speed: 0.0ms preprocess, 544.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Extracted text: Aed
#
# ...
